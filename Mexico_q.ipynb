# %%
#Importamos pandas, numpy y matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mexico = pd.read_csv('Mexico.csv')

# %%
#Verficamos informacion del Dataframe
mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26281 non-null  int64
#  1   name                            26281 non-null  object
#  2   host_id                         26281 non-null  int64
#  3   host_name                       26278 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   26281 non-null  object
#  6   latitude                        26281 non-null  float64
#  7   longitude                       26281 non-null  float64
#  8   room_type                       26281 non-null  object
#  9   price                           22466 non-null  float64
#  10  minimum_nights                  26281 non-null  int64
#  11  number_of_reviews               26281 non-null  int64
#  12  last_review                     22985 non-null  object
#  13  reviews_per_month               22985 non-null  float64
#  14  calculated_host_listings_count  26281 non-null  int64
#  15  availability_365                26281 non-null  int64
#  16  number_of_reviews_ltm           26281 non-null  int64
#  17  license                         0 non-null      float64
# dtypes: float64(6), int64(7), object(5)
# memory usage: 3.6+ MB

# %%
valores_nulos=mexico.isnull().sum() #para que me lo de en columnas
valores_nulos
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             3
# neighbourhood_group               26281
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              3815
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        3296
# reviews_per_month                  3296
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           26281
# dtype: int64

# %%
data1 = mexico.fillna(method="bfill")
data1 = mexico.fillna(method="ffill")
data1["license"] = data1["license"].fillna(0)
data1
# Out:
# /var/folders/cr/23ck8vtn1kd8mbhg9wssxh440000gn/T/ipykernel_7294/2321813780.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 = mexico.fillna(method="bfill")
# /var/folders/cr/23ck8vtn1kd8mbhg9wssxh440000gn/T/ipykernel_7294/2321813780.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data1 = mexico.fillna(method="ffill")
#                         id                                               name  \
# 0                   499553      Deluxe 4-BR penthouse, views, historic center
# 1                   501037                The best cheap flat in La Condesa!!
# 2                   517503                         Nice big room near airport
# 3                   527473  Nuestro bello departamento, un paraíso en la C...
# 4                   544105  Polanco great location! Priv Room in Shared Apart
# ...                    ...                                                ...
# 26276  1318906185008171760                             Suite Dumas Polanco 8D
# 26277  1318960023050066631                     Departamento amueblado en CDMX
# 26278  1318997244771691320                         hospedaje en Coyoacán CDMX
# 26279  1319078571963617776            3 recámaras 3 baños con estacionamiento
# 26280  1319509843525848258  Loft ejecutivo junto a Reforma y a pasos del Á...
#
#          host_id         host_name  neighbourhood_group        neighbourhood  \
# 0        1297488             Petra                  NaN           Cuauhtémoc
# 1        1364145          Humberto                  NaN           Cuauhtémoc
# 2        2547499      Irma Adriana                  NaN  Venustiano Carranza
# 3         158585          Fernando                  NaN           Cuauhtémoc
# 4        2674950         Elizabeth                  NaN       Miguel Hidalgo
# ...          ...               ...                  ...                  ...
# 26276  369403303          Grissell                  NaN       Miguel Hidalgo
# 26277  525554527           Partner                  NaN           Cuauhtémoc
# 26278  293574406  Bellanira Isabel                  NaN             Coyoacán
# 26279   35255741              Juan                  NaN       Miguel Hidalgo
# 26280  333035396              Clau                  NaN           Cuauhtémoc
#
#         latitude  longitude        room_type   price  minimum_nights  \
# 0      19.436210 -99.138740  Entire home/apt  4985.0               3
# 1      19.415780 -99.174250  Entire home/apt  1150.0               5
# 2      19.437840 -99.079030     Private room   550.0               1
# 3      19.418870 -99.173330  Entire home/apt  3654.0               1
# 4      19.442892 -99.201385     Private room  1007.0               2
# ...          ...        ...              ...     ...             ...
# 26276  19.436998 -99.196733     Private room   760.0               1
# 26277  19.449230 -99.136170  Entire home/apt  8897.0               1
# 26278  19.316820 -99.116781      Shared room   227.0               3
# 26279  19.400096 -99.172981  Entire home/apt  3125.0               1
# 26280  19.427799 -99.163842  Entire home/apt   918.0               1
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                     26  2024-10-28               0.17
# 1                    134  2024-12-03               0.89
# 2                    281  2024-12-11               3.43
# 3                    354  2024-12-02               2.35
# 4                     67  2024-11-26               0.74
# ...                  ...         ...                ...
# 26276                  0  2024-12-26               1.00
# 26277                  0  2024-12-26               1.00
# 26278                  0  2024-12-26               1.00
# 26279                  0  2024-12-26               1.00
# 26280                  0  2024-12-26               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   2               117
# 1                                   2               232
# 2                                   1               339
# 3                                   1               216
# 4                                   1               173
# ...                               ...               ...
# 26276                              12               363
# 26277                               1               365
# 26278                               8               365
# 26279                              31               359
# 26280                             183               325
#
#        number_of_reviews_ltm  license
# 0                          1      0.0
# 1                         23      0.0
# 2                         52      0.0
# 3                         32      0.0
# 4                          9      0.0
# ...                      ...      ...
# 26276                      0      0.0
# 26277                      0      0.0
# 26278                      0      0.0
# 26279                      0      0.0
# 26280                      0      0.0
#
# [26281 rows x 18 columns]

# %%
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %%
#Creo 2 dataframe para poder procesar los outliers
cuantitativas = data1.select_dtypes(include=['float64', 'int64', 'float', 'int'])
cualitativas = data1.select_dtypes(include=['object','datetime','category'])

# %%
data1["neighbourhood_group"] = data1["neighbourhood_group"].fillna(0)

# %%
#Realizamos diagrama de caja o bigote de cada columna del dataframe
fig = plt.figure(figsize=(15, 8))
cuantitativas.plot(kind='box', vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
fig = plt.figure(figsize=(15, 8))#el size lo pones tu para que mida lo que quieras ejemplo, 15x8cm
cuantitativas['reviews_per_month'].plot(kind='box', vert=False)
plt.title("Valores Atipicos del Dataframe")
plt.show() #dibujamos el diagrama

# %%
#Para detectar el rango intercuartilico 
y = cuantitativas

percentiles25 = y.quantile(0.25) #Q1 medida estandar del 25%
percentiles75 = y.quantile(0.75) #Q2 medida estandar que toma encuenta la suma de los demas 25% de los cuantiles
iqr = percentiles75 - percentiles25

limite_superior_iqr = percentiles75 + 1.5*iqr
limite_inferior_iqr = percentiles25 - 1.5*iqr
print("limite superior permitido ", limite_superior_iqr)
print("limite inferior permitido "), limite_inferior_iqr
# Out:
# limite superior permitido  id                                2.600145e+18
# host_id                           8.860262e+08
# neighbourhood_group                        NaN
# latitude                          1.949298e+01
# longitude                        -9.911830e+01
# price                             3.691500e+03
# minimum_nights                    3.500000e+00
# number_of_reviews                 1.480000e+02
# reviews_per_month                 5.645000e+00
# calculated_host_listings_count    2.600000e+01
# availability_365                  7.390000e+02
# number_of_reviews_ltm             5.500000e+01
# license                           0.000000e+00
# dtype: float64
# limite inferior permitido
# (None,
#  id                               -1.560087e+18
#  host_id                          -4.492911e+08
#  neighbourhood_group                        NaN
#  latitude                          1.933010e+01
#  longitude                        -9.921539e+01
#  price                            -1.152500e+03
#  minimum_nights                   -5.000000e-01
#  number_of_reviews                -8.400000e+01
#  reviews_per_month                -2.635000e+00
#  calculated_host_listings_count   -1.400000e+01
#  availability_365                 -3.010000e+02
#  number_of_reviews_ltm            -3.300000e+01
#  license                           0.000000e+00
#  dtype: float64)

# %%
#identifica los outliers que tenemos en nuestro diagrama
data3_iqr = cuantitativas[(y<=limite_superior_iqr)&(y>=limite_inferior_iqr)]
data3_iqr
# Out:
#                         id    host_id  neighbourhood_group   latitude  \
# 0                   499553    1297488                  NaN  19.436210
# 1                   501037    1364145                  NaN  19.415780
# 2                   517503    2547499                  NaN  19.437840
# 3                   527473     158585                  NaN  19.418870
# 4                   544105    2674950                  NaN  19.442892
# ...                    ...        ...                  ...        ...
# 26276  1318906185008171760  369403303                  NaN  19.436998
# 26277  1318960023050066631  525554527                  NaN  19.449230
# 26278  1318997244771691320  293574406                  NaN        NaN
# 26279  1319078571963617776   35255741                  NaN  19.400096
# 26280  1319509843525848258  333035396                  NaN  19.427799
#
#        longitude   price  minimum_nights  number_of_reviews  \
# 0     -99.138740     NaN             3.0               26.0
# 1     -99.174250  1150.0             NaN              134.0
# 2            NaN   550.0             1.0                NaN
# 3     -99.173330  3654.0             1.0                NaN
# 4     -99.201385  1007.0             2.0               67.0
# ...          ...     ...             ...                ...
# 26276 -99.196733   760.0             1.0                0.0
# 26277 -99.136170     NaN             1.0                0.0
# 26278        NaN   227.0             3.0                0.0
# 26279 -99.172981  3125.0             1.0                0.0
# 26280 -99.163842   918.0             1.0                0.0
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.17                             2.0               117
# 1                   0.89                             2.0               232
# 2                   3.43                             1.0               339
# 3                   2.35                             1.0               216
# 4                   0.74                             1.0               173
# ...                  ...                             ...               ...
# 26276               1.00                            12.0               363
# 26277               1.00                             1.0               365
# 26278               1.00                             8.0               365
# 26279               1.00                             NaN               359
# 26280               1.00                             NaN               325
#
#        number_of_reviews_ltm  license
# 0                        1.0      0.0
# 1                       23.0      0.0
# 2                       52.0      0.0
# 3                       32.0      0.0
# 4                        9.0      0.0
# ...                      ...      ...
# 26276                    0.0      0.0
# 26277                    0.0      0.0
# 26278                    0.0      0.0
# 26279                    0.0      0.0
# 26280                    0.0      0.0
#
# [26281 rows x 13 columns]

# %%
#nos dice cuantos outliers tenemos
valores_nulos = data3_iqr.isnull().sum()
valores_nulos
# Out:
# id                                    0
# host_id                               0
# neighbourhood_group               26281
# latitude                           1812
# longitude                          2843
# price                              2188
# minimum_nights                     3523
# number_of_reviews                  2177
# reviews_per_month                   986
# calculated_host_listings_count     3380
# availability_365                      0
# number_of_reviews_ltm              1207
# license                               0
# dtype: int64

# %%
data4_iqr=data3_iqr.copy()
data4_iqr=data4_iqr.fillna(round(data3_iqr.mean(),1))
data4_iqr
# Out:
#                         id    host_id  neighbourhood_group   latitude  \
# 0                   499553    1297488                  NaN  19.436210
# 1                   501037    1364145                  NaN  19.415780
# 2                   517503    2547499                  NaN  19.437840
# 3                   527473     158585                  NaN  19.418870
# 4                   544105    2674950                  NaN  19.442892
# ...                    ...        ...                  ...        ...
# 26276  1318906185008171760  369403303                  NaN  19.436998
# 26277  1318960023050066631  525554527                  NaN  19.449230
# 26278  1318997244771691320  293574406                  NaN  19.400000
# 26279  1319078571963617776   35255741                  NaN  19.400096
# 26280  1319509843525848258  333035396                  NaN  19.427799
#
#        longitude   price  minimum_nights  number_of_reviews  \
# 0     -99.138740  1216.8             3.0               26.0
# 1     -99.174250  1150.0             1.6              134.0
# 2     -99.200000   550.0             1.0               30.1
# 3     -99.173330  3654.0             1.0               30.1
# 4     -99.201385  1007.0             2.0               67.0
# ...          ...     ...             ...                ...
# 26276 -99.196733   760.0             1.0                0.0
# 26277 -99.136170  1216.8             1.0                0.0
# 26278 -99.200000   227.0             3.0                0.0
# 26279 -99.172981  3125.0             1.0                0.0
# 26280 -99.163842   918.0             1.0                0.0
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   0.17                             2.0               117
# 1                   0.89                             2.0               232
# 2                   3.43                             1.0               339
# 3                   2.35                             1.0               216
# 4                   0.74                             1.0               173
# ...                  ...                             ...               ...
# 26276               1.00                            12.0               363
# 26277               1.00                             1.0               365
# 26278               1.00                             8.0               365
# 26279               1.00                             5.0               359
# 26280               1.00                             5.0               325
#
#        number_of_reviews_ltm  license
# 0                        1.0      0.0
# 1                       23.0      0.0
# 2                       52.0      0.0
# 3                       32.0      0.0
# 4                        9.0      0.0
# ...                      ...      ...
# 26276                    0.0      0.0
# 26277                    0.0      0.0
# 26278                    0.0      0.0
# 26279                    0.0      0.0
# 26280                    0.0      0.0
#
# [26281 rows x 13 columns]

# %%
data4_iqr["neighbourhood_group"] = data4_iqr["neighbourhood_group"].fillna(0)

# %%
datos_limpios = pd.concat([cualitativas, data4_iqr], axis=1)
datos_limpios
# Out:
#                                                     name         host_name  \
# 0          Deluxe 4-BR penthouse, views, historic center             Petra
# 1                    The best cheap flat in La Condesa!!          Humberto
# 2                             Nice big room near airport      Irma Adriana
# 3      Nuestro bello departamento, un paraíso en la C...          Fernando
# 4      Polanco great location! Priv Room in Shared Apart         Elizabeth
# ...                                                  ...               ...
# 26276                             Suite Dumas Polanco 8D          Grissell
# 26277                     Departamento amueblado en CDMX           Partner
# 26278                         hospedaje en Coyoacán CDMX  Bellanira Isabel
# 26279            3 recámaras 3 baños con estacionamiento              Juan
# 26280  Loft ejecutivo junto a Reforma y a pasos del Á...              Clau
#
#              neighbourhood        room_type last_review                   id  \
# 0               Cuauhtémoc  Entire home/apt  2024-10-28               499553
# 1               Cuauhtémoc  Entire home/apt  2024-12-03               501037
# 2      Venustiano Carranza     Private room  2024-12-11               517503
# 3               Cuauhtémoc  Entire home/apt  2024-12-02               527473
# 4           Miguel Hidalgo     Private room  2024-11-26               544105
# ...                    ...              ...         ...                  ...
# 26276       Miguel Hidalgo     Private room  2024-12-26  1318906185008171760
# 26277           Cuauhtémoc  Entire home/apt  2024-12-26  1318960023050066631
# 26278             Coyoacán      Shared room  2024-12-26  1318997244771691320
# 26279       Miguel Hidalgo  Entire home/apt  2024-12-26  1319078571963617776
# 26280           Cuauhtémoc  Entire home/apt  2024-12-26  1319509843525848258
#
#          host_id  neighbourhood_group   latitude  longitude   price  \
# 0        1297488                  0.0  19.436210 -99.138740  1216.8
# 1        1364145                  0.0  19.415780 -99.174250  1150.0
# 2        2547499                  0.0  19.437840 -99.200000   550.0
# 3         158585                  0.0  19.418870 -99.173330  3654.0
# 4        2674950                  0.0  19.442892 -99.201385  1007.0
# ...          ...                  ...        ...        ...     ...
# 26276  369403303                  0.0  19.436998 -99.196733   760.0
# 26277  525554527                  0.0  19.449230 -99.136170  1216.8
# 26278  293574406                  0.0  19.400000 -99.200000   227.0
# 26279   35255741                  0.0  19.400096 -99.172981  3125.0
# 26280  333035396                  0.0  19.427799 -99.163842   918.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                 3.0               26.0               0.17
# 1                 1.6              134.0               0.89
# 2                 1.0               30.1               3.43
# 3                 1.0               30.1               2.35
# 4                 2.0               67.0               0.74
# ...               ...                ...                ...
# 26276             1.0                0.0               1.00
# 26277             1.0                0.0               1.00
# 26278             3.0                0.0               1.00
# 26279             1.0                0.0               1.00
# 26280             1.0                0.0               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                 2.0               117
# 1                                 2.0               232
# 2                                 1.0               339
# 3                                 1.0               216
# 4                                 1.0               173
# ...                               ...               ...
# 26276                            12.0               363
# 26277                             1.0               365
# 26278                             8.0               365
# 26279                             5.0               359
# 26280                             5.0               325
#
#        number_of_reviews_ltm  license
# 0                        1.0      0.0
# 1                       23.0      0.0
# 2                       52.0      0.0
# 3                       32.0      0.0
# 4                        9.0      0.0
# ...                      ...      ...
# 26276                    0.0      0.0
# 26277                    0.0      0.0
# 26278                    0.0      0.0
# 26279                    0.0      0.0
# 26280                    0.0      0.0
#
# [26281 rows x 18 columns]

# %%
valores_nulos=data4_iqr.isnull().sum()
valores_nulos
# Out:
# id                                0
# host_id                           0
# neighbourhood_group               0
# latitude                          0
# longitude                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %%
datos_limpios.to_csv("Mexico_limpios.csv")
